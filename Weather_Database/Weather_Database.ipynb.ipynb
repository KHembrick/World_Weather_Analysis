# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 727

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
         # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | klaksvik
# Processing Record 9 of Set 1 | saint-michel-des-saints
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | liuli
# Processing Record 13 of Set 1 | archidona
# Processing Record 14 of Set 1 | ixtapa
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | zyryanka
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | sentyabrskiy
# City not found. Skipping
# Processing Record 21 of Set 1 | nelson bay
# Processing Record 22 of Set 1 | bacuit
# City not found. Skipping
# Processing Record 23 of Set 1 | fort william
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | hofn
# Processing Record 26 of Set 1 | port hedland
# Processing Record 27 of Set 1 | vestmannaeyjar
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | port augusta
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | kulhudhuffushi
# Processing Record 32 of Set 1 | norman wells
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | manbij
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | emerald
# Processing Record 39 of Set 1 | constitucion
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | boyolangu
# Processing Record 42 of Set 1 | millau
# Processing Record 43 of Set 1 | tura
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | tselinnoye
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | cacador
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 11 of Set 2 | puerto del rosario
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | waipawa
# Processing Record 14 of Set 2 | bull savanna
# Processing Record 15 of Set 2 | mega
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | san quintin
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | kharovsk
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | bonavista
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | kupang
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | turukhansk
# Processing Record 28 of Set 2 | mittagong
# Processing Record 29 of Set 2 | daru
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | namibe
# Processing Record 33 of Set 2 | yarada
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | vaitupu
# City not found. Skipping
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | catamarca
# Processing Record 39 of Set 2 | henties bay
# Processing Record 40 of Set 2 | kunming
# Processing Record 41 of Set 2 | kenai
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 43 of Set 2 | waingapu
# Processing Record 44 of Set 2 | plettenberg bay
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | midyat
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | ternate
# Processing Record 1 of Set 3 | buqayq
# City not found. Skipping
# Processing Record 2 of Set 3 | avera
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | jiuquan
# Processing Record 5 of Set 3 | manzil salim
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 8 of Set 3 | yuksekova
# Processing Record 9 of Set 3 | aksu
# Processing Record 10 of Set 3 | sorland
# Processing Record 11 of Set 3 | khandbari
# Processing Record 12 of Set 3 | zemio
# Processing Record 13 of Set 3 | louisbourg
# City not found. Skipping
# Processing Record 14 of Set 3 | ketchikan
# Processing Record 15 of Set 3 | abrau-dyurso
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | pompeu
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | karema
# Processing Record 22 of Set 3 | saleaula
# City not found. Skipping
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | lagoa da prata
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | filadelfia
# Processing Record 27 of Set 3 | ambilobe
# Processing Record 28 of Set 3 | ola
# Processing Record 29 of Set 3 | pisco
# Processing Record 30 of Set 3 | khromtau
# Processing Record 31 of Set 3 | lucapa
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | jinxi
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | kudahuvadhoo
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping
# Processing Record 37 of Set 3 | sojat
# Processing Record 38 of Set 3 | hovd
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | erenhot
# Processing Record 41 of Set 3 | altamont
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | axim
# Processing Record 44 of Set 3 | chifeng
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | te anau
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | padang
# Processing Record 49 of Set 3 | mogwase
# Processing Record 50 of Set 3 | chicama
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | mantua
# Processing Record 3 of Set 4 | touba
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | awjilah
# Processing Record 8 of Set 4 | qaqortoq
# Processing Record 9 of Set 4 | cheremnoye
# Processing Record 10 of Set 4 | letnyaya stavka
# Processing Record 11 of Set 4 | polunochnoye
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping
# Processing Record 13 of Set 4 | surin
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | charlestown
# Processing Record 17 of Set 4 | yamada
# Processing Record 18 of Set 4 | mandalgovi
# Processing Record 19 of Set 4 | lamar
# Processing Record 20 of Set 4 | eureka
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | bow island
# Processing Record 23 of Set 4 | aktash
# Processing Record 24 of Set 4 | jasper
# Processing Record 25 of Set 4 | road town
# Processing Record 26 of Set 4 | windhoek
# Processing Record 27 of Set 4 | brownsville
# Processing Record 28 of Set 4 | new norfolk
# Processing Record 29 of Set 4 | bolungarvik
# City not found. Skipping
# Processing Record 30 of Set 4 | grand river south east
# City not found. Skipping
# Processing Record 31 of Set 4 | pudozh
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | ugoofaaru
# Processing Record 34 of Set 4 | tabiauea
# City not found. Skipping
# Processing Record 35 of Set 4 | taseyevo
# Processing Record 36 of Set 4 | fairbanks
# Processing Record 37 of Set 4 | santa isabel do rio negro
# Processing Record 38 of Set 4 | batagay
# Processing Record 39 of Set 4 | jertih
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | kobojango
# City not found. Skipping
# Processing Record 42 of Set 4 | yuancheng
# Processing Record 43 of Set 4 | hobyo
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | ribas do rio pardo
# Processing Record 46 of Set 4 | takoradi
# Processing Record 47 of Set 4 | tenosique
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | rocha
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | talcahuano
# Processing Record 3 of Set 5 | carahue
# Processing Record 4 of Set 5 | baiao
# Processing Record 5 of Set 5 | nanortalik
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | kukuna
# Processing Record 8 of Set 5 | macatuba
# Processing Record 9 of Set 5 | seymchan
# Processing Record 10 of Set 5 | labranzagrande
# Processing Record 11 of Set 5 | ranau
# Processing Record 12 of Set 5 | jumla
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | tilichiki
# Processing Record 16 of Set 5 | huarmey
# Processing Record 17 of Set 5 | strezhevoy
# Processing Record 18 of Set 5 | ales
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | beyneu
# Processing Record 22 of Set 5 | mackay
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | nishihara
# Processing Record 25 of Set 5 | areosa
# Processing Record 26 of Set 5 | vostok
# Processing Record 27 of Set 5 | panguipulli
# Processing Record 28 of Set 5 | kupino
# Processing Record 29 of Set 5 | ambon
# Processing Record 30 of Set 5 | porechye-rybnoye
# Processing Record 31 of Set 5 | kalevala
# Processing Record 32 of Set 5 | vao
# Processing Record 33 of Set 5 | ratnagiri
# Processing Record 34 of Set 5 | upington
# Processing Record 35 of Set 5 | sayyan
# Processing Record 36 of Set 5 | mullaitivu
# City not found. Skipping
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | sur
# Processing Record 39 of Set 5 | chisindia
# Processing Record 40 of Set 5 | yatou
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | college
# Processing Record 43 of Set 5 | honiara
# Processing Record 44 of Set 5 | penzance
# Processing Record 45 of Set 5 | bahawalpur
# Processing Record 46 of Set 5 | roald
# Processing Record 47 of Set 5 | mar del plata
# Processing Record 48 of Set 5 | niksic
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | kloulklubed
# Processing Record 1 of Set 6 | bougouni
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | batagay-alyta
# Processing Record 4 of Set 6 | mizpe ramon
# City not found. Skipping
# Processing Record 5 of Set 6 | tessalit
# Processing Record 6 of Set 6 | gizo
# Processing Record 7 of Set 6 | zhitikara
# City not found. Skipping
# Processing Record 8 of Set 6 | sarmizegetusa
# Processing Record 9 of Set 6 | belaya gora
# Processing Record 10 of Set 6 | onda
# Processing Record 11 of Set 6 | mehamn
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping
# Processing Record 13 of Set 6 | kapuskasing
# Processing Record 14 of Set 6 | concepcion del uruguay
# Processing Record 15 of Set 6 | pachino
# Processing Record 16 of Set 6 | oksfjord
# Processing Record 17 of Set 6 | aba
# Processing Record 18 of Set 6 | grand gaube
# Processing Record 19 of Set 6 | gijon
# Processing Record 20 of Set 6 | troitsko-pechorsk
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | visby
# Processing Record 23 of Set 6 | marcona
# City not found. Skipping
# Processing Record 24 of Set 6 | beboto
# Processing Record 25 of Set 6 | labuhan
# Processing Record 26 of Set 6 | samarai
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | gladstone
# Processing Record 29 of Set 6 | half moon bay
# Processing Record 30 of Set 6 | bolshegrivskoye
# City not found. Skipping
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | sinnamary
# Processing Record 33 of Set 6 | aklavik
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | straumen
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | vila franca do campo
# Processing Record 38 of Set 6 | fare
# Processing Record 39 of Set 6 | evensk
# Processing Record 40 of Set 6 | rawson
# Processing Record 41 of Set 6 | tanout
# Processing Record 42 of Set 6 | antigonish
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | conceicao do araguaia
# Processing Record 45 of Set 6 | san lorenzo
# Processing Record 46 of Set 6 | loubomo
# Processing Record 47 of Set 6 | kil
# Processing Record 48 of Set 6 | bubaque
# Processing Record 49 of Set 6 | bom jesus
# Processing Record 50 of Set 6 | ina
# Processing Record 1 of Set 7 | high level
# Processing Record 2 of Set 7 | poya
# Processing Record 3 of Set 7 | touros
# Processing Record 4 of Set 7 | bathsheba
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | the valley
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | ndele
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | east london
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | obo
# Processing Record 14 of Set 7 | alyangula
# Processing Record 15 of Set 7 | sao felix do xingu
# Processing Record 16 of Set 7 | hami
# Processing Record 17 of Set 7 | sovetskaya gavan
# Processing Record 18 of Set 7 | ambovombe
# Processing Record 19 of Set 7 | angoche
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | olafsvik
# Processing Record 23 of Set 7 | ponta do sol
# Processing Record 24 of Set 7 | havelock
# Processing Record 25 of Set 7 | samusu
# City not found. Skipping
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | sogdiondon
# City not found. Skipping
# Processing Record 28 of Set 7 | dalvik
# Processing Record 29 of Set 7 | srednekolymsk
# Processing Record 30 of Set 7 | pakxe
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | isangel
# Processing Record 33 of Set 7 | kasongo-lunda
# Processing Record 34 of Set 7 | finschhafen
# Processing Record 35 of Set 7 | abnub
# Processing Record 36 of Set 7 | kyra
# Processing Record 37 of Set 7 | bitung
# Processing Record 38 of Set 7 | nadym
# Processing Record 39 of Set 7 | bandarbeyla
# Processing Record 40 of Set 7 | borger
# Processing Record 41 of Set 7 | yurimaguas
# Processing Record 42 of Set 7 | amga
# Processing Record 43 of Set 7 | buala
# Processing Record 44 of Set 7 | karaton
# Processing Record 45 of Set 7 | americana
# Processing Record 46 of Set 7 | port elizabeth
# Processing Record 47 of Set 7 | morros
# Processing Record 48 of Set 7 | tsihombe
# City not found. Skipping
# Processing Record 49 of Set 7 | san ciro de acosta
# Processing Record 50 of Set 7 | yulara
# Processing Record 1 of Set 8 | siavonga
# Processing Record 2 of Set 8 | beloha
# Processing Record 3 of Set 8 | kuche
# City not found. Skipping
# Processing Record 4 of Set 8 | kamenskoye
# City not found. Skipping
# Processing Record 5 of Set 8 | egvekinot
# Processing Record 6 of Set 8 | doha
# Processing Record 7 of Set 8 | vega de alatorre
# Processing Record 8 of Set 8 | rawlins
# Processing Record 9 of Set 8 | mirabad
# Processing Record 10 of Set 8 | luderitz
# Processing Record 11 of Set 8 | liberal
# Processing Record 12 of Set 8 | aykhal
# Processing Record 13 of Set 8 | kultuk
# Processing Record 14 of Set 8 | sarankhola
# Processing Record 15 of Set 8 | phan rang
# City not found. Skipping
# Processing Record 16 of Set 8 | fuerte olimpo
# Processing Record 17 of Set 8 | belmonte
# Processing Record 18 of Set 8 | pierre
# Processing Record 19 of Set 8 | inderborskiy
# City not found. Skipping
# Processing Record 20 of Set 8 | duma
# Processing Record 21 of Set 8 | paragominas
# Processing Record 22 of Set 8 | raga
# Processing Record 23 of Set 8 | gazanjyk
# Processing Record 24 of Set 8 | black river
# Processing Record 25 of Set 8 | morondava
# Processing Record 26 of Set 8 | comodoro rivadavia
# Processing Record 27 of Set 8 | krasnoselkup
# Processing Record 28 of Set 8 | alindao
# Processing Record 29 of Set 8 | ferrol
# Processing Record 30 of Set 8 | sidrolandia
# Processing Record 31 of Set 8 | wau
# Processing Record 32 of Set 8 | zhigansk
# Processing Record 33 of Set 8 | binga
# Processing Record 34 of Set 8 | kruisfontein
# Processing Record 35 of Set 8 | khilok
# Processing Record 36 of Set 8 | nome
# Processing Record 37 of Set 8 | alice springs
# Processing Record 38 of Set 8 | port-gentil
# Processing Record 39 of Set 8 | bafq
# Processing Record 40 of Set 8 | inhambupe
# Processing Record 41 of Set 8 | kamenka
# Processing Record 42 of Set 8 | kasamwa
# Processing Record 43 of Set 8 | pitea
# Processing Record 44 of Set 8 | xingtai
# Processing Record 45 of Set 8 | peterhead
# Processing Record 46 of Set 8 | ullapool
# Processing Record 47 of Set 8 | zeya
# Processing Record 48 of Set 8 | sistranda
# Processing Record 49 of Set 8 | thunder bay
# Processing Record 50 of Set 8 | lebu
# Processing Record 1 of Set 9 | zonguldak
# Processing Record 2 of Set 9 | roznava
# Processing Record 3 of Set 9 | asau
# Processing Record 4 of Set 9 | nogent-le-rotrou
# Processing Record 5 of Set 9 | bokspits
# City not found. Skipping
# Processing Record 6 of Set 9 | uwayl
# City not found. Skipping
# Processing Record 7 of Set 9 | tatawin
# Processing Record 8 of Set 9 | dukat
# Processing Record 9 of Set 9 | vaitape
# Processing Record 10 of Set 9 | yakeshi
# Processing Record 11 of Set 9 | porto novo
# Processing Record 12 of Set 9 | geraldton
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | tam ky
# Processing Record 15 of Set 9 | iqaluit
# Processing Record 16 of Set 9 | chenzhou
# Processing Record 17 of Set 9 | yenagoa
# Processing Record 18 of Set 9 | port moresby
# Processing Record 19 of Set 9 | misratah
# Processing Record 20 of Set 9 | tautira
# Processing Record 21 of Set 9 | wellington
# Processing Record 22 of Set 9 | ilulissat
# Processing Record 23 of Set 9 | la asuncion
# Processing Record 24 of Set 9 | sebu
# Processing Record 25 of Set 9 | bisert
# Processing Record 26 of Set 9 | chapleau
# Processing Record 27 of Set 9 | umarkot
# Processing Record 28 of Set 9 | tokonou
# Processing Record 29 of Set 9 | kolosovka
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | wucheng
# Processing Record 32 of Set 9 | gezing
# Processing Record 33 of Set 9 | jaciara
# Processing Record 34 of Set 9 | opuwo
# Processing Record 35 of Set 9 | strelka
# Processing Record 36 of Set 9 | agaro
# Processing Record 37 of Set 9 | nenjiang
# Processing Record 38 of Set 9 | amapa
# Processing Record 39 of Set 9 | newport
# Processing Record 40 of Set 9 | rawannawi
# City not found. Skipping
# Processing Record 41 of Set 9 | kurilsk
# Processing Record 42 of Set 9 | vagur
# Processing Record 43 of Set 9 | kaohsiung
# Processing Record 44 of Set 9 | shenxian
# Processing Record 45 of Set 9 | svetlyy
# Processing Record 46 of Set 9 | shenzhen
# Processing Record 47 of Set 9 | dondo
# Processing Record 48 of Set 9 | sept-iles
# Processing Record 49 of Set 9 | skotterud
# Processing Record 50 of Set 9 | mwense
# Processing Record 1 of Set 10 | haines junction
# Processing Record 2 of Set 10 | yeletskiy
# City not found. Skipping
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | mitu
# Processing Record 5 of Set 10 | east bethel
# Processing Record 6 of Set 10 | bad doberan
# Processing Record 7 of Set 10 | tabas
# Processing Record 8 of Set 10 | teahupoo
# Processing Record 9 of Set 10 | tarsus
# Processing Record 10 of Set 10 | kommunisticheskiy
# Processing Record 11 of Set 10 | palmetto
# Processing Record 12 of Set 10 | buraydah
# Processing Record 13 of Set 10 | onega
# Processing Record 14 of Set 10 | tigil
# Processing Record 15 of Set 10 | ajdabiya
# Processing Record 16 of Set 10 | gold coast
# Processing Record 17 of Set 10 | san cristobal
# Processing Record 18 of Set 10 | treinta y tres
# Processing Record 19 of Set 10 | beisfjord
# Processing Record 20 of Set 10 | saint-paul
# Processing Record 21 of Set 10 | wulanhaote
# City not found. Skipping
# Processing Record 22 of Set 10 | hay river
# Processing Record 23 of Set 10 | hauterive
# Processing Record 24 of Set 10 | grand-santi
# Processing Record 25 of Set 10 | tubruq
# City not found. Skipping
# Processing Record 26 of Set 10 | zhongxing
# Processing Record 27 of Set 10 | mogzon
# Processing Record 28 of Set 10 | wewak
# Processing Record 29 of Set 10 | samalaeulu
# City not found. Skipping
# Processing Record 30 of Set 10 | halifax
# Processing Record 31 of Set 10 | mulege
# Processing Record 32 of Set 10 | antalaha
# Processing Record 33 of Set 10 | contramaestre
# Processing Record 34 of Set 10 | siutu
# City not found. Skipping
# Processing Record 35 of Set 10 | port macquarie
# Processing Record 36 of Set 10 | adrar
# Processing Record 37 of Set 10 | paranhos
# Processing Record 38 of Set 10 | timbo
# Processing Record 39 of Set 10 | lilongwe
# Processing Record 40 of Set 10 | athabasca
# Processing Record 41 of Set 10 | neudorfl
# Processing Record 42 of Set 10 | inuvik
# Processing Record 43 of Set 10 | kafanchan
# Processing Record 44 of Set 10 | coquimbo
# Processing Record 45 of Set 10 | san francisco
# Processing Record 46 of Set 10 | pangnirtung
# Processing Record 47 of Set 10 | fortuna
# Processing Record 48 of Set 10 | fomboni
# Processing Record 49 of Set 10 | kadykchan
# City not found. Skipping
# Processing Record 50 of Set 10 | menongue
# Processing Record 1 of Set 11 | caraballeda
# Processing Record 2 of Set 11 | dong hoi
# Processing Record 3 of Set 11 | elizabeth city
# Processing Record 4 of Set 11 | cauquenes
# Processing Record 5 of Set 11 | los llanos de aridane
# Processing Record 6 of Set 11 | kamina
# Processing Record 7 of Set 11 | frisco
# Processing Record 8 of Set 11 | uyskoye
# Processing Record 9 of Set 11 | senmonorom
# City not found. Skipping
# Processing Record 10 of Set 11 | aflu
# City not found. Skipping
# Processing Record 11 of Set 11 | coihaique
# Processing Record 12 of Set 11 | vallenar
# Processing Record 13 of Set 11 | saint-augustin
# Processing Record 14 of Set 11 | toliary
# City not found. Skipping
# Processing Record 15 of Set 11 | rzhanitsa
# Processing Record 16 of Set 11 | saldanha
# Processing Record 17 of Set 11 | sangmelima
# Processing Record 18 of Set 11 | camocim
# Processing Record 19 of Set 11 | gravdal
# Processing Record 20 of Set 11 | pringsewu
# Processing Record 21 of Set 11 | kinablangan
# Processing Record 22 of Set 11 | prudentopolis
# Processing Record 23 of Set 11 | kiama
# Processing Record 24 of Set 11 | riyadh
# Processing Record 25 of Set 11 | faanui
# Processing Record 26 of Set 11 | saint-louis
# Processing Record 27 of Set 11 | cayenne
# Processing Record 28 of Set 11 | kimry
# Processing Record 29 of Set 11 | khandyga
# Processing Record 30 of Set 11 | beringovskiy
# Processing Record 31 of Set 11 | hit
# Processing Record 32 of Set 11 | bonthe
# Processing Record 33 of Set 11 | marawi
# Processing Record 34 of Set 11 | north bend
# Processing Record 35 of Set 11 | tezu
# Processing Record 36 of Set 11 | macaboboni
# City not found. Skipping
# Processing Record 37 of Set 11 | uige
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | khangarh
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | nuuk
# Processing Record 42 of Set 11 | whitehorse
# Processing Record 43 of Set 11 | cacule
# Processing Record 44 of Set 11 | dongsheng
# Processing Record 45 of Set 11 | nurota
# Processing Record 46 of Set 11 | smithers
# Processing Record 47 of Set 11 | tyukalinsk
# Processing Record 48 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping
# Processing Record 49 of Set 11 | moranbah
# Processing Record 50 of Set 11 | bayanday
# Processing Record 1 of Set 12 | mikuni
# Processing Record 2 of Set 12 | pueblo nuevo
# Processing Record 3 of Set 12 | havre-saint-pierre
# Processing Record 4 of Set 12 | verkhnyaya inta
# Processing Record 5 of Set 12 | atasu
# Processing Record 6 of Set 12 | new ulm
# Processing Record 7 of Set 12 | santa maria
# Processing Record 8 of Set 12 | davidson
# Processing Record 9 of Set 12 | grajau
# Processing Record 10 of Set 12 | pichayevo
# Processing Record 11 of Set 12 | tawkar
# City not found. Skipping
# Processing Record 12 of Set 12 | qingyuan
# Processing Record 13 of Set 12 | zachepylivka
# Processing Record 14 of Set 12 | alta floresta
# Processing Record 15 of Set 12 | la paz centro
# Processing Record 16 of Set 12 | udachnyy
# Processing Record 17 of Set 12 | jalu
# Processing Record 18 of Set 12 | marsabit
# Processing Record 19 of Set 12 | zambezi
# Processing Record 20 of Set 12 | aksarka
# Processing Record 21 of Set 12 | rovnoye
# Processing Record 22 of Set 12 | cap malheureux
# Processing Record 23 of Set 12 | svetlogorsk
# Processing Record 24 of Set 12 | afua
# Processing Record 25 of Set 12 | malwan
# City not found. Skipping
# Processing Record 26 of Set 12 | fiumicino
# Processing Record 27 of Set 12 | sembe
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | stropkov
# Processing Record 30 of Set 12 | puerto princesa
# Processing Record 31 of Set 12 | victoria
# Processing Record 32 of Set 12 | balakhninskiy
# Processing Record 33 of Set 12 | wadhwan
# City not found. Skipping
# Processing Record 34 of Set 12 | shatalovo
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | antofagasta
# Processing Record 37 of Set 12 | jinchang
# Processing Record 38 of Set 12 | katima mulilo
# Processing Record 39 of Set 12 | brigantine
# Processing Record 40 of Set 12 | ravar
# Processing Record 41 of Set 12 | rongcheng
# Processing Record 42 of Set 12 | pangkalanbuun
# Processing Record 43 of Set 12 | faya
# Processing Record 44 of Set 12 | humaita
# Processing Record 45 of Set 12 | panzhihua
# Processing Record 46 of Set 12 | gushikawa
# Processing Record 47 of Set 12 | necochea
# Processing Record 48 of Set 12 | blackwater
# Processing Record 49 of Set 12 | dakar
# Processing Record 50 of Set 12 | iquique
# Processing Record 1 of Set 13 | bukama
# Processing Record 2 of Set 13 | oyama
# Processing Record 3 of Set 13 | mehran
# Processing Record 4 of Set 13 | gerash
# Processing Record 5 of Set 13 | ngukurr
# City not found. Skipping
# Processing Record 6 of Set 13 | yeppoon
# Processing Record 7 of Set 13 | khani
# Processing Record 8 of Set 13 | wapi pathum
# Processing Record 9 of Set 13 | tingrela
# City not found. Skipping
# Processing Record 10 of Set 13 | solwezi
# Processing Record 11 of Set 13 | lasa
# Processing Record 12 of Set 13 | griffith
# Processing Record 13 of Set 13 | kochinda
# Processing Record 14 of Set 13 | fort myers beach
# Processing Record 15 of Set 13 | komsomolskiy
# Processing Record 16 of Set 13 | san luis
# Processing Record 17 of Set 13 | sopiste
# City not found. Skipping
# Processing Record 18 of Set 13 | inverell
# Processing Record 19 of Set 13 | lolua
# City not found. Skipping
# Processing Record 20 of Set 13 | makakilo city
# Processing Record 21 of Set 13 | buchanan
# Processing Record 22 of Set 13 | cangzhou
# Processing Record 23 of Set 13 | khonuu
# City not found. Skipping
# Processing Record 24 of Set 13 | saint anthony
# Processing Record 25 of Set 13 | tyret pervaya
# Processing Record 26 of Set 13 | la ronge
# Processing Record 27 of Set 13 | saint-pierre
# Processing Record 28 of Set 13 | salamanca
# Processing Record 29 of Set 13 | cortland
# Processing Record 30 of Set 13 | ewa beach
# Processing Record 31 of Set 13 | maceio
# Processing Record 32 of Set 13 | osoyoos
# Processing Record 33 of Set 13 | nabire
# Processing Record 34 of Set 13 | bardiyah
# Processing Record 35 of Set 13 | gat
# Processing Record 36 of Set 13 | baffa
# Processing Record 37 of Set 13 | palabuhanratu
# City not found. Skipping
# Processing Record 38 of Set 13 | canton
# Processing Record 39 of Set 13 | lazaro cardenas
# Processing Record 40 of Set 13 | zdanice
# Processing Record 41 of Set 13 | preobrazheniye
# Processing Record 42 of Set 13 | quatre cocos
# Processing Record 43 of Set 13 | tarudant
# City not found. Skipping
# Processing Record 44 of Set 13 | san rafael
# Processing Record 45 of Set 13 | matagami
# Processing Record 46 of Set 13 | namalenga
# Processing Record 47 of Set 13 | joshimath
# Processing Record 48 of Set 13 | sakakah
# Processing Record 49 of Set 13 | rio grande
# Processing Record 50 of Set 13 | gazojak
# Processing Record 1 of Set 14 | qandala
# Processing Record 2 of Set 14 | zaysan
# Processing Record 3 of Set 14 | mitsukaido
# Processing Record 4 of Set 14 | slidell
# Processing Record 5 of Set 14 | gemena
# Processing Record 6 of Set 14 | fort nelson
# Processing Record 7 of Set 14 | ercis
# Processing Record 8 of Set 14 | alofi
# Processing Record 9 of Set 14 | almaznyy
# Processing Record 10 of Set 14 | grindavik
# Processing Record 11 of Set 14 | colares
# Processing Record 12 of Set 14 | mogadishu
# Processing Record 13 of Set 14 | mizque
# Processing Record 14 of Set 14 | caconda
# Processing Record 15 of Set 14 | tahoua
# Processing Record 16 of Set 14 | stornoway
# Processing Record 17 of Set 14 | medeiros neto
# Processing Record 18 of Set 14 | urumqi
# Processing Record 19 of Set 14 | yinchuan
# Processing Record 20 of Set 14 | orangeburg
# Processing Record 21 of Set 14 | muyezerskiy
# Processing Record 22 of Set 14 | akdepe
# Processing Record 23 of Set 14 | radcliff
# Processing Record 24 of Set 14 | el alto
# Processing Record 25 of Set 14 | liverpool
# Processing Record 26 of Set 14 | yabelo
# Processing Record 27 of Set 14 | bud
# Processing Record 28 of Set 14 | yerbogachen
# Processing Record 29 of Set 14 | tianpeng
# Processing Record 30 of Set 14 | malibu
# Processing Record 31 of Set 14 | manzil tamim
# City not found. Skipping
# Processing Record 32 of Set 14 | zhezkazgan
# Processing Record 33 of Set 14 | chernyshevskiy
# Processing Record 34 of Set 14 | marzuq
# Processing Record 35 of Set 14 | rassvet
# Processing Record 36 of Set 14 | marathon
# Processing Record 37 of Set 14 | baley
# Processing Record 38 of Set 14 | santa cruz
# Processing Record 39 of Set 14 | ulaanbaatar
# Processing Record 40 of Set 14 | phuntsholing
# Processing Record 41 of Set 14 | paoua
# Processing Record 42 of Set 14 | tual
# Processing Record 43 of Set 14 | howard springs
# Processing Record 44 of Set 14 | sant julia de loria
# Processing Record 45 of Set 14 | albesti
# Processing Record 46 of Set 14 | bloomfield
# Processing Record 47 of Set 14 | natal
# Processing Record 48 of Set 14 | karpathos
# Processing Record 49 of Set 14 | guane
# Processing Record 50 of Set 14 | lima
# Processing Record 1 of Set 15 | satitoa
# City not found. Skipping
# Processing Record 2 of Set 15 | sines
# Processing Record 3 of Set 15 | tasbuget
# City not found. Skipping
# Processing Record 4 of Set 15 | pacific grove
# Processing Record 5 of Set 15 | swidnik
# Processing Record 6 of Set 15 | saquarema
# Processing Record 7 of Set 15 | la peca
# Processing Record 8 of Set 15 | namanyere
# Processing Record 9 of Set 15 | vyazemskiy
# Processing Record 10 of Set 15 | pochutla
# Processing Record 11 of Set 15 | kaoma
# Processing Record 12 of Set 15 | charleston
# Processing Record 13 of Set 15 | alamosa
# Processing Record 14 of Set 15 | charleville-mezieres
# Processing Record 15 of Set 15 | kieta
# Processing Record 16 of Set 15 | kalmunai
# Processing Record 17 of Set 15 | ust-ordynskiy
# Processing Record 18 of Set 15 | general delgado
# Processing Record 19 of Set 15 | sao jose da coroa grande
# Processing Record 20 of Set 15 | skoghall
# Processing Record 21 of Set 15 | kysyl-syr
# Processing Record 22 of Set 15 | karratha
# Processing Record 23 of Set 15 | rudbar
# Processing Record 24 of Set 15 | muros
# Processing Record 25 of Set 15 | flin flon
# Processing Record 26 of Set 15 | maraa
# Processing Record 27 of Set 15 | uzventis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 669

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0                  Rikitea      PF  2022-02-12 07:55:19 -23.1203 -134.9692
# 1                Mahebourg      MU  2022-02-12 07:55:19 -20.4081   57.7000
# 2                Jamestown      US  2022-02-12 07:55:20  42.0970  -79.2353
# 3                  Ushuaia      AR  2022-02-12 07:52:47 -54.8000  -68.3000
# 4             Puerto Ayora      EC  2022-02-12 07:55:20  -0.7393  -90.3518
# 5                   Hasaki      JP  2022-02-12 07:55:20  35.7333  140.8333
# 6                 Klaksvik      FO  2022-02-12 07:55:21  62.2266   -6.5890
# 7  Saint-Michel-Des-Saints      CA  2022-02-12 07:52:42  46.6834  -73.9159
# 8                   Albany      US  2022-02-12 07:51:52  42.6001  -73.9662
# 9                     Hilo      US  2022-02-12 07:50:41  19.7297 -155.0900
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     78.94        73           8       17.52          light rain
# 1     84.25        78          40       13.80    scattered clouds
# 2     38.08        66         100       11.01     overcast clouds
# 3     51.46        62          40       51.79    scattered clouds
# 4     71.55        97         100        1.01     overcast clouds
# 5     48.29        52         100        6.20     overcast clouds
# 6     41.92        97         100       20.02     overcast clouds
# 7     31.93        98         100        8.68     overcast clouds
# 8     50.58        62         100        6.64     overcast clouds
# 9     68.61        92           1        3.00           clear sky

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
